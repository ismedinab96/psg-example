# %% [markdown]
# # Adivina la Carta
# El juego consiste en adivinar si la carta posterior a la que se muestra es mayor o menor, gana el que mayor acierto tenga, pierde quien acumula 3 derrotas.

# %% [markdown]
# Reglas del juego:
# 1. El juego debe ser jugado minimamente entre dos jugadores"
# 2. Se debe tener una baraja española, barajeada"
# 3. Un jugado es el juez y los demas adivinan"
# 5. El jugador pierde su turno si se equivoca, y se anota una X"
# 4. El juez saca una carta de la parte superior de la carta, el siguiente jugador debe adivinar si la siguiente carta es mayor o menor"
# 6. Gana quien adivina la mayor cantidad de cartas o en su defecto quien acumula 3 Xs"

# %%
print("------------------------------------------------------------------------------")
print("|                           Adivina la carta                                 |")
print("|                                                                            |")
print("|                                                                            |")
print("|                                                                            |")
print("|                   ------------------------                                 |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   |                       |                                |")
print("|                   ------------------------                                 |")
print("|                                                                            |")
print("|                                                                            |")
print("|                                                                            |")
print("|                                                                            |")
print("|                                                                            |")
print("|                                                                            |")
print("------------------------------------------------------------------------------")

# %% [markdown]
# Cartas Disponibles:
# 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , 9 , J , Q , K , A
# El Joker actua como comodin.
# Todas las cartas deben barajearse

# %%
cA = f"""
    ┌─────────┐
    │ A       │
    │         │
    │         │
    │         │
    │      A  │
    └─────────┘
    """
c1 = f"""
    ┌─────────┐
    │ 1       │
    │         │
    │         │
    │         │
    │      1  │
    └─────────┘
    """
c2 = f"""
    ┌─────────┐
    │ 2       │
    │         │
    │         │
    │         │
    │      2  │
    └─────────┘
    """
c3 = f"""
    ┌─────────┐
    │ 3       │
    │         │
    │         │
    │         │
    │      3  │
    └─────────┘
    """
c4 = f"""
    ┌─────────┐
    │ 4       │
    │         │
    │         │
    │         │
    │      4  │
    └─────────┘
    """
c5 = f"""
    ┌─────────┐
    │ 5       │
    │         │
    │         │
    │         │
    │      5  │
    └─────────┘
    """
c6 = f"""
    ┌─────────┐
    │ 6       │
    │         │
    │         │
    │         │
    │      6  │
    └─────────┘
    """
c7 = f"""
    ┌─────────┐
    │ 7       │
    │         │
    │         │
    │         │
    │      7  │
    └─────────┘
    """
c8 = f"""
    ┌─────────┐
    │ 8       │
    │         │
    │         │
    │         │
    │      8  │
    └─────────┘
    """
c9 = f"""
    ┌─────────┐
    │ 9       │
    │         │
    │         │
    │         │
    │      9  │
    └─────────┘
    """
cJ = f"""
    ┌─────────┐
    │ J       │
    │         │
    │         │
    │         │
    │      J  │
    └─────────┘
    """
cQ = f"""
    ┌─────────┐
    │ Q       │
    │         │
    │         │
    │         │
    │      Q  │
    └─────────┘
    """
cK = f"""
    ┌─────────┐
    │ K       │
    │         │
    │         │
    │         │
    │      K  │
    └─────────┘
    """
